# %% [markdown]
# # Python Lists, Tuples, Sets, and Dictionaries
#
# **Instructions:** Review the online material at links below. Run the code blocks so the output for each code block shows in your notebook. Code blocks in the **Code Challenge** sections require you to enter code before you run it. You need to have the correct output showing for all code cells to receive full credit.
#
# ## Review Python Operators
#
# Review the pages in the W3Schools __[Python Operators](https://www.w3schools.com/python/python_operators.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Create two variables a = 15 and b = 4
#
# Print the result of a modulus b (the % operator)
#
# Print the result of a floor division b (the // operator)
#
# Print the result of a to the power of b (the ** operator)
#
# Use an assignment operator to add 10 to a (use +=)

# %%
# Create variables

# Print modulus

# Print floor division

# Print power

# Add 10 to a

# %%
a = 15
b = 4

print(a % b)
print(a // b)
print(a ** b)

a += 10
print(a)
# Out:
# 3
# 3
# 50625
# 25

# %% [markdown]
# ## Review Python Lists
#
# Review the pages in the W3Schools __[Python Lists](https://www.w3schools.com/python/python_lists.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Create a list called colors with the values "red", "green", "blue"
#
# Print the first item in the list
#
# Change the second item to "yellow"
#
# Add "purple" to the end of the list using append()
#
# Remove "red" from the list using remove()
#
# Print the list

# %%
# Create a list

# Print the first item

# Change the second item to "yellow"

# Add "purple" to the end

# Remove "red"

# Print the list

# %%
colors = ["red", "green", "blue"]
print(colors[0])
colors[1] = "yellow"
colors.append("purple")
colors.remove("red")
print(colors)
# Out:
# red
# ['yellow', 'blue', 'purple']

# %% [markdown]
# ## Review Python Tuples
#
# Review the pages in the W3Schools __[Python Tuples](https://www.w3schools.com/python/python_tuples.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Create a tuple called fruits with the values "apple", "banana", "cherry"
#
# Print the second item in the tuple
#
# Print the number of items using len()
#
# Unpack the tuple into three variables a, b, c
#
# Print the variable b

# %%
# Create the tuple

# Print the second item

# Print the number of items

# Unpack the tuple

# Print b

# %%
fruits = ("apple", "banana", "cherry")
print(fruits[1])
print(len(fruits))
a, b, c = fruits
print(b)
# Out:
# banana
# 3
# banana

# %% [markdown]
# ## Review Python Sets
#
# Review the pages in the W3Schools __[Python Sets](https://www.w3schools.com/python/python_sets.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Create a set called colors with the values "red", "green", "blue"
#
# Print the set
#
# Add "yellow" to the set using add()
#
# Remove "green" from the set using discard()
#
# Print the number of items using len()

# %%
# Create the set

# Print the set

# Add "yellow"

# Remove "green"

# Print the number of items

# %%
colors = {"red", "green", "blue"}
print(colors)
colors.add("yellow")
colors.discard("green")
print(len(colors))
# Out:
# {'blue', 'green', 'red'}
# 3

# %% [markdown]
# ## Review Python Dictionaries
#
# Review the pages in the __[Python Dictionaries](https://www.w3schools.com/python/python_dictionaries.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Create a dictionary called car with the keys "brand", "model", "year" and values "Ford", "Mustang", 2024
#
# Print the value of the "model" key
#
# Add a new key "color" with the value "red"
#
# Remove the "brand" key using pop()
#
# Print the dictionary

# %%
# Create the dictionary

# Print the model

# Add a color key

# Remove the brand key

# Print the dictionary

# %%
car = {"brand": "Ford", "model": "Mustang", "year": 2024}
print(car["model"])
car["color"] = "red"
car.pop("brand")
print(car)
# Out:
# Mustang
# {'model': 'Mustang', 'year': 2024, 'color': 'red'}

# %% [markdown]
# ## Review Python Arrays
#
# Review the pages in the __[Python Arrays](https://www.w3schools.com/python/python_arrays.asp)__ section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Create a list called cars with the values "Ford", "Volvo", "BMW"
#
# Print the first item in the list
#
# Change the second item to "Toyota"
#
# Print the list

# %%
# Create a list

# Print the first item

# Change the second item to "Toyota"

# Print the list

# %%
cars = ["Ford", "Volvo", "BMW"]
print(cars[0])
cars[1] = "Toyota"
print(cars)
# Out:
# Ford
# ['Ford', 'Toyota', 'BMW']

# %% [markdown]
# ## Submit Your Assignment
#
# * Add "_complete" to the end of the name of this notebook.
# * Save the notebook. (File - Save)
# * Download the notebook. (File - Download - Download .ipynb)
# * Upload your notebook to your GitHub repository. (__[Upload files to GitHub](https://github.com/cmcntsh/N6429_GitHubForClassAssignments#upload-files-directly-to-github)__)
# * Submit your repository link in Canvas.
